# %% [markdown]
# # Learning basic programming concepts
# - This notebook is used for learning and understanding the basic concepts of Python. Don't be afraid of the code.
# - My goal is to learn to run the code and be able to explain it to others in a simple way.

# %%
print("Hello, World!")
# Out:
# Hello, World!
